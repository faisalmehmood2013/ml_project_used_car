# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">👨‍💻 1. EDA & Model Trainning for Used Cars Dataset 😃😃</p>

# %% [markdown]
# ![cars.jpeg](attachment:cars.jpeg)

# %% [markdown]
# <div style="border-radius:10px; border:#000000 solid; padding: 20px; background-color: black; font-size:16px; color: #ffffff; text-align:center; width: 70%; margin: auto;">
# <h3 style="color:#D00000; margin-bottom: 20px;">Author's Information</h3>
#
# **Written by:** Faisal Mehmood
# **Submission Date:** 06-04-2024
# **Email:** [shahfaisal1234@gmail.com](mailto:shahfaisal1234@gmail.com)
#
# <h3 style="color:#D00000; margin-bottom: 20px;">Contact with me</h3>
#
# [<img src="https://raw.githubusercontent.com/FortAwesome/Font-Awesome/6.x/svgs/brands/linkedin.svg" width="40" height="40" alt="LinkedIn" style="background-color: #ffffff; border-radius: 8px; padding: 5px;">](https://www.linkedin.com/in/fmehmood1122/)
# [<img src="https://raw.githubusercontent.com/FortAwesome/Font-Awesome/6.x/svgs/brands/github.svg" width="40" height="40" alt="GitHub" style="background-color: #ffffff; border-radius: 8px; padding: 5px;">](https://github.com/faisalmehmood2013)
# [<img src="https://raw.githubusercontent.com/FortAwesome/Font-Awesome/6.x/svgs/brands/facebook.svg" width="40" height="40" alt="Facebook" style="background-color: #ffffff; border-radius: 8px; padding: 5px;">](https://www.facebook.com/FMGillani01)
# [<img src="https://raw.githubusercontent.com/FortAwesome/Font-Awesome/6.x/svgs/brands/instagram.svg" width="40" height="40" alt="Instagram" style="background-color: #ffffff; border-radius: 8px; padding: 5px;">](https://www.instagram.com/fmgillani/)

# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">📊 About the Dataset</p>

# %% [markdown]
# <div style="border-radius:10px; border:#000000 solid; padding: 20px; background-color: black; font-size:16px; color: #ffffff; text-align:left; width: 70%; margin: auto;">
# <h3 style="color:#D00000; margin-bottom: 20px;">About the Dataset:</h3>
#
# The **Used Car Price Prediction Dataset** is a comprehensive collection of automotive data sourced from the popular online marketplace [Cars.com](https://www.cars.com). It consists of **4,009 unique vehicle listings**, each described by **nine key features** that provide valuable insights for price prediction, consumer analysis, and automotive market research.
#
# 1. 🔹 Key Features:
#     1. **Brand & Model**: Specifies the manufacturer and model of each car.
#     2. **Model Year**: Indicates the year of manufacture, essential for understanding depreciation and technological relevance.
#     3. **Mileage**: Shows the total distance a vehicle has traveled, which is a critical factor in determining wear and potential maintenance.
#     4. **Fuel Type**: Denotes the fuel category—Gasoline, Diesel, Electric, or Hybrid—affecting fuel economy and environmental impact.
#     5. **Engine Type**: Details the engine specifications, contributing to performance analysis and efficiency evaluation.
#     6. **Transmission**: Indicates the type of gear system—Automatic, Manual, or other types.
#     7. **Exterior & Interior Colors**: Reflects the vehicle's appearance, highlighting both exterior and interior color schemes.
#     8. **Accident History**: Reveals whether the vehicle has been involved in any accidents or has sustained damage, vital for assessing risk.
#     9. **Clean Title**: States whether the vehicle holds a clean title, impacting its resale value and legal status.
#     10. **Price**: Displays the listed sale price, which serves as the **target variable** for prediction.
#
# 2. 📁 Dataset Summary:
#     - **Source**: [Used Cars Dataset](https://www.kaggle.com/datasets/taeefnajib/used-car-price-prediction-dataset/data)
#     - **Total Records**: 4,009
#     - **Use Case**: Used car price prediction, consumer behavior analysis, market trend analysis
#
# 3. 📌 Usefulness:
# This dataset is an excellent resource for:
#     - Automotive price prediction projects
#     - Machine learning model development
#     - Data analysis on consumer preferences and car features
#     - Informed decision-making for car buyers and sellers

# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">🔧 Problem Statement: Used Cars Price Prediction</p>

# %% [markdown]
# <div style="border-radius:10px; border:#000000 solid; padding: 20px; background-color: black; font-size:16px; color: #ffffff; text-align:left; width: 70%; margin: auto;">
# <h3 style="color:#D00000; margin-bottom: 20px;">Problem Statement:</h3>
#
# Buying a used car can be a challenging task due to price variations, unclear vehicle conditions, and a lack of standard pricing metrics. Many buyers often overpay or underpay due to the absence of reliable and data-driven insights.
#
# The goal of this project is to build a predictive model that can estimate the fair market price of a used car based on various features such as brand, model, manufacturing year, mileage, fuel type, transmission etc.
#
# By analyzing historical data of used car sales, we aim to:
#
# * Help buyers make informed purchasing decisions.
#
# * Assist sellers in setting competitive and fair prices.
#
# * Reduce information asymmetry in the used car market.

# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">🎯 Objectives</p>

# %% [markdown]
# <div style="border-radius:10px; border:#000000 solid; padding: 20px; background-color: black; font-size:16px; color: #ffffff; text-align:left; width: 70%; margin: auto;">
# <h3 style="color:#D00000; margin-bottom: 20px;">Objectives:</h3>
#
# * To analyze and clean the used car dataset.
#
# * To identify key factors that influence the price of used cars.
#
# * To build and evaluate machine learning models for price prediction.
#
# * To develop a user-friendly interface where users can input car details and get a predicted price.
#
# * To assist users in understanding market trends and fair pricing for used cars.

# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">✅ Tasks</p>

# %% [markdown]
# <div style="border-radius:10px; border:#000000 solid; padding: 20px; background-color: black; font-size:16px; color: #ffffff; text-align:left; width: 70%; margin: auto;">
# <h3 style="color:#D00000; margin-bottom: 20px;">Tasks:</h3>
#
# 1. Data Collection
#    - Gather a dataset containing used car listings with features like price, brand, model, year, mileage, fuel type, transmission, etc.
#
# 2. Data Preprocessing
#    - Handle missing values
#    - Remove duplicates
#    - Encode categorical variables
#    - Normalize or scale numeric features
#
# 3. Exploratory Data Analysis (EDA)
#    - Analyze data distribution
#    - Visualize feature relationships with price
#    - Detect and treat outliers
#
# 4. Feature Engineering
#    - Create or transform useful features
#    - Select important variables for modeling
#
# 5. Model Building
#    - Train multiple regression models (e.g., Linear Regression, Random Forest, XGBoost)
#    - Evaluate models using MAE, RMSE, and R²
#
# 6. Model Optimization
#    - Tune hyperparameters
#    - Address overfitting/underfitting issues
#
# 7. Deployment
#    - Build a web application using Streamlit or Flask
#    - Allow users to input car details and receive price predictions
#
# 8. Documentation & Reporting
#    - Document the workflow, code, and results
#    - Create visualizations and summary reports

# %% [markdown]
# <div style="border-radius:10px; border:#000000 solid; padding: 20px; background-color: black; font-size:16px; color: #ffffff; text-align:center; width: 90%; margin: auto;">
# <h1 style="color:#D00000; margin-bottom: 20px;">Please Upvote my kernel if you like my work.</h1>

# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">Import Libraries</p>

# %%
# 📦 Data Handling
import pandas as pd
import numpy as np

# 📊 Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# 🧹 Data Preprocessing
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, OrdinalEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, MaxAbsScaler, QuantileTransformer, PowerTransformer, Normalizer, Binarizer


# 🤖 Machine Learning Models (Regression Problem)
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# 🛠 Warnings
import warnings
warnings.filterwarnings("ignore")

# 🧾 Display Settings
pd.set_option('display.max_columns', None)
